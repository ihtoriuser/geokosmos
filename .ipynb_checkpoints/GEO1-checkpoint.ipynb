# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
help(geopandas)
# Out:
# Help on package geopandas:
#
# NAME
#     geopandas
#
# PACKAGE CONTENTS
#     _compat
#     _config
#     _decorator
#     _vectorized
#     _version
#     array
#     base
#     conftest
#     datasets (package)
#     explore
#     geodataframe
#     geoseries
#     io (package)
#     plotting
#     sindex
#     testing
#     tests (package)
#     tools (package)
#
# DATA
#     options = Options(
#       display_precision: None [default: Non...e``. Opti...
#
# VERSION
#     0.14.2
#
# FILE
#     c:\users\user\anaconda3\lib\site-packages\geopandas\__init__.py

# %%
# Importing an ESRI Shapefile and plotting it using GeoPandas
districts = gpd.read_file('D:\GEO\Shapefiles\Shapefiles\districts.shp')
districts.plot(cmap = 'hsv', edgecolor = 'black', column = 'district')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\user\AppData\Local\Temp\ipykernel_6580\1423053149.py:2: SyntaxWarning: invalid escape sequence '\G'
#   districts = gpd.read_file('D:\GEO\Shapefiles\Shapefiles\districts.shp')
# <Axes: >

# %%
districts
# Out:
#                                 district  \
# 0                 Newry, Mourne and Down
# 1                             Mid Ulster
# 2                    Mid and East Antrim
# 3                Lisburn and Castlereagh
# 4   Armagh City, Banbridge and Craigavon
# 5                Antrim and Newtownabbey
# 6                    Ards and North Down
# 7                    Fermanagh and Omagh
# 8                Derry City and Strabane
# 9               Causeway Coast and Glens
# 10                               Belfast
#
#                                              geometry
# 0   POLYGON ((-5.82139 54.49408, -5.82128 54.49399...
# 1   POLYGON ((-6.53263 54.94913, -6.53253 54.94901...
# 2   POLYGON ((-5.96917 55.05284, -5.96909 55.05284...
# 3   POLYGON ((-6.08760 54.62414, -6.08699 54.62394...
# 4   POLYGON ((-6.27820 54.54965, -6.27819 54.54960...
# 5   POLYGON ((-6.16426 54.81062, -6.16405 54.81063...
# 6   MULTIPOLYGON (((-5.74192 54.67759, -5.74190 54...
# 7   POLYGON ((-6.99814 54.78009, -6.99806 54.78010...
# 8   POLYGON ((-7.25762 55.06648, -7.25759 55.06648...
# 9   MULTIPOLYGON (((-6.48405 55.25194, -6.48401 55...
# 10  POLYGON ((-5.92755 54.65170, -5.92732 54.65155...

# %%
districts.plot()
# Out:
# <Axes: >

# %%
area_of_interest = gpd.read_file('D:/GEO/Shapefiles/Shapefiles/area_of_interest.shp')
area_of_interest.plot()
# Out:
# <Axes: >

# %%
# Plot the figures side by side 
fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (10,8))
districts.plot(ax = ax1, cmap = 'hsv', edgecolor = 'black', column = 'district')
area_of_interest.plot(ax = ax2, color = 'green')
# Out:
# <Axes: >

# %%
atms = gpd.read_file('D:/GEO/Shapefiles/Shapefiles/atms.shp')
atms.plot()
# Out:
# <Axes: >

# %%
# Plotting multiple layers
fig, ax = plt.subplots(figsize = (10,8))
districts.plot(ax = ax, cmap = 'hsv', edgecolor = 'black', column = 'district')
area_of_interest.plot(ax = ax, color = 'none', edgecolor = 'black')
atms.plot(ax = ax, color = 'black', markersize = 14)
# Out:
# <Axes: >

# %%
districts.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Reprojecting GeoPandas GeoDataFrames
fig, ax = plt.subplots(figsize = (8,6))
districts = districts.to_crs(epsg = 32629)
districts.plot(ax = ax, cmap = 'hsv', edgecolor = 'black', column = 'district')
area_of_interest = area_of_interest.to_crs(epsg = 32629)
area_of_interest.plot(ax = ax, color = 'none', edgecolor = 'black')
# Out:
# <Axes: >

# %%
# Intersecting Layers
districts_in_aoi = gpd.overlay(districts, area_of_interest, how = 'intersection')
districts_in_aoi.plot(edgecolor = 'red')
# Out:
# <Axes: >

# %%
# Calculating the areas of the intersected layer 
districts_in_aoi['area'] = districts_in_aoi.area/1000000  #km2
districts_in_aoi
# Out:
#                                district  Id  \
# 0                            Mid Ulster   0
# 1                   Mid and East Antrim   0
# 2               Lisburn and Castlereagh   0
# 3  Armagh City, Banbridge and Craigavon   0
# 4               Antrim and Newtownabbey   0
# 5                   Fermanagh and Omagh   0
# 6               Derry City and Strabane   0
# 7              Causeway Coast and Glens   0
#
#                                             geometry         area
# 0  POLYGON ((658017.072 6091916.291, 658023.630 6...  1574.420076
# 1  POLYGON ((684916.646 6077240.234, 684908.771 6...   373.691057
# 2  POLYGON ((685894.696 6035736.759, 685894.090 6...   151.737874
# 3  MULTIPOLYGON (((676032.651 6048086.094, 676033...   553.932816
# 4  POLYGON ((682226.240 6077404.748, 682239.947 6...   462.822918
# 5  POLYGON ((628746.570 6072158.485, 628751.931 6...   262.996444
# 6  POLYGON ((622292.459 6091384.089, 622292.384 6...   187.500979
# 7  POLYGON ((671302.332 6097252.019, 671301.064 6...   747.580677

# %%
from shapely.geometry import Point
from descartes import PolygonPatch

# %%
type(Point(1,1).buffer(1))
# Out:
# shapely.geometry.polygon.Polygon

# %%
Point(1,1).buffer(1)
# Out:
# <POLYGON ((2 1, 2 0.902, 1.98 0.805, 1.96 0.71, 1.92 0.617, 1.88 0.529, 1.83...>

# %%
fig,ax = plt.subplots()
ax.set_xlim(0,3)
ax.set_ylim(0,2)

#circle = Point(1, 1).buffer(1)
#c1 = PolygonPatch(circle, color="blue", alpha=0.5)
type(Point(1,1).buffer(1))

#c1 = PolygonPatch(Point(1,1).buffer(1))
#c2 = PolygonPatch(Point(2,1).buffer(1))

#ax.add_artist(c1)
#ax.add_patch(c2)
# Out:
# shapely.geometry.polygon.Polygon
